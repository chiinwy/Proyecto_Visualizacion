# %%
import pandas as pd

# %%
# vamos a ver el nuevo csv

# %%
data = pd.read_csv(r"C:\Users\chiin\Desktop\Proyecto_Visualizacion\data\Game_of_Thrones.csv")

data
# Out:
#     Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0        1                        1                         1
# 1        1                        2                         2
# 2        1                        3                         3
# 3        1                        4                         4
# 4        1                        5                         5
# ..     ...                      ...                       ...
# 68       8                        2                        69
# 69       8                        3                        70
# 70       8                        4                        71
# 71       8                        5                        72
# 72       8                        6                        73
#
#                      Title of the Episode  Running Time (Minutes)  \
# 0                        Winter Is Coming                      61
# 1                           The Kingsroad                      55
# ...

# %%
data.shape
# Out:
# (73, 19)

# %%
data.dtypes
# Out:
# Season                                   int64
# No. of Episode (Season)                  int64
# No. of Episode (Overall)                 int64
# Title of the Episode                    object
# Running Time (Minutes)                   int64
# Directed by                             object
# Written by                              object
# Original Air Date                       object
# U.S. Viewers (Millions)                float64
# Music by                                object
# Cinematography by                       object
# Editing by                              object
# IMDb Rating                            float64
# Rotten Tomatoes Rating (Percentage)      int64
# Metacritic Ratings                     float64
# Ordered                                 object
# Filming Duration                        object
# Novel(s) Adapted                        object
# Synopsis                                object
# dtype: object

# %%
data.columns = [col.lower().replace(' ', '') for col in data.columns]
data.columns = data.columns.str.strip()

data.columns
# Out:
# Index(['season', 'no.ofepisode(season)', 'no.ofepisode(overall)',
#        'titleoftheepisode', 'runningtime(minutes)', 'directedby', 'writtenby',
#        'originalairdate', 'u.s.viewers(millions)', 'musicby',
#        'cinematographyby', 'editingby', 'imdbrating',
#        'rottentomatoesrating(percentage)', 'metacriticratings', 'ordered',
#        'filmingduration', 'novel(s)adapted', 'synopsis'],
#       dtype='object')

# %%
data['season'] = data['season'].astype('object')
data['no.ofepisode(season)'] = data['no.ofepisode(season)'].astype('object')
data['no.ofepisode(overall)'] = data['no.ofepisode(overall)'].astype('object')

# %%
data.dtypes
# Out:
# season                               object
# no.ofepisode(season)                 object
# no.ofepisode(overall)                object
# titleoftheepisode                    object
# runningtime(minutes)                  int64
# directedby                           object
# writtenby                            object
# originalairdate                      object
# u.s.viewers(millions)               float64
# musicby                              object
# cinematographyby                     object
# editingby                            object
# imdbrating                          float64
# rottentomatoesrating(percentage)      int64
# metacriticratings                   float64
# ordered                              object
# filmingduration                      object
# novel(s)adapted                      object
# synopsis                             object
# dtype: object

# %%
data.to_csv('C:\\Users\\chiin\\Desktop\\got_clean.csv', index=False)

# %%
data.head(10)
# Out:
#   season no.ofepisode(season) no.ofepisode(overall)  \
# 0      1                    1                     1
# 1      1                    2                     2
# 2      1                    3                     3
# 3      1                    4                     4
# 4      1                    5                     5
# 5      1                    6                     6
# 6      1                    7                     7
# 7      1                    8                     8
# 8      1                    9                     9
# 9      1                   10                    10
#
#                        titleoftheepisode  runningtime(minutes)  \
# 0                       Winter Is Coming                    61
# 1                          The Kingsroad                    55
# 2                              Lord Snow                    57
# 3  Cripples, Bastards, and Broken Things                    55
# 4                  The Wolf and the Lion                    54
# ...

# %%
data.head()
# Out:
#   season no.ofepisode(season) no.ofepisode(overall)  \
# 0      1                    1                     1
# 1      1                    2                     2
# 2      1                    3                     3
# 3      1                    4                     4
# 4      1                    5                     5
#
#                        titleoftheepisode  runningtime(minutes)  \
# 0                       Winter Is Coming                    61
# 1                          The Kingsroad                    55
# 2                              Lord Snow                    57
# 3  Cripples, Bastards, and Broken Things                    55
# 4                  The Wolf and the Lion                    54
#
#        directedby                   writtenby originalairdate  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss     17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss     24-Apr-2011
# 2      Brian Kirk  David Benioff, D. B. Weiss      1-May-2011
# ...

# %%
data['imdbrating'] = data['imdbrating'].astype(str)

data['metacriticratings'] = data['metacriticratings'].astype(str)

data['u.s.viewers(millions)'] = data['u.s.viewers(millions)'].astype(str)

# %%
data.dtypes
# Out:
# season                              object
# no.ofepisode(season)                object
# no.ofepisode(overall)               object
# titleoftheepisode                   object
# runningtime(minutes)                 int64
# directedby                          object
# writtenby                           object
# originalairdate                     object
# u.s.viewers(millions)               object
# musicby                             object
# cinematographyby                    object
# editingby                           object
# imdbrating                          object
# rottentomatoesrating(percentage)     int64
# metacriticratings                   object
# ordered                             object
# filmingduration                     object
# novel(s)adapted                     object
# synopsis                            object
# dtype: object

# %%
data['imdbrating'] = data['imdbrating'].str.replace('.', ',')

data['metacriticratings'] = data['metacriticratings'].str.replace('.', ',')

data['u.s.viewers(millions)'] = data['u.s.viewers(millions)'].str.replace('.', ',')

data.head()
# Out:
# C:\Users\chiin\AppData\Local\Temp\ipykernel_7536\1308522892.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['imdbrating'] = data['imdbrating'].str.replace('.', ',')
# C:\Users\chiin\AppData\Local\Temp\ipykernel_7536\1308522892.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['metacriticratings'] = data['metacriticratings'].str.replace('.', ',')
# C:\Users\chiin\AppData\Local\Temp\ipykernel_7536\1308522892.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
data.to_csv(r'C:\Users\chiin\Desktop\Proyecto_Visualizacion\data\got_clean.csv', index=False)
